# %% [markdown]
# # Enterprise RAG LangChain Platform
#
# This notebook runs the LangChain-based hybrid RAG pipeline over the warehouse built by the companion data platform project.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path
import os

BASE = Path('/content/drive/MyDrive/projects/enterprise-rag-langchain-platform')
DATA_PLATFORM_BASE = Path('/content/drive/MyDrive/projects/modern-data-platform-blueprint')
WAREHOUSE_DB = DATA_PLATFORM_BASE / 'data' / 'warehouse' / 'warehouse.db'
os.chdir(BASE)
os.environ['WAREHOUSE_DB'] = str(WAREHOUSE_DB)
print('Warehouse DB exists:', WAREHOUSE_DB.exists())
print('Repo files:', os.listdir(BASE))
# Out:
# Warehouse DB exists: True
# Repo files: ['notebooks', 'app', 'src', 'data', 'docs', 'README.md', 'requirements.txt']

# %%
# !pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 91.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 191.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 40.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 22.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 37.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 131.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 31.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 85.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.1/459.1 kB 61.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 102.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 183.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 157.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 68.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 8.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# langgraph-prebuilt 1.0.9 requires langchain-core>=1.0.0, but you have langchain-core 0.3.84 which is incompatible.
# google-adk 1.29.0 requires tenacity<10.0.0,>=9.0.0, but you have tenacity 8.5.0 which is incompatible.
# google-adk 1.29.0 requires watchdog<7.0.0,>=6.0.0, but you have watchdog 4.0.2 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.

# %%
# !python -m src.build_sample_docs
# !python -m src.extract_sql_context
# !python -m src.ingest_documents
# !python -m src.build_langchain_indexes
# !python -m src.run_demo
# Out:
# Wrote 4 documents to /content/drive/MyDrive/projects/enterprise-rag-langchain-platform/docs
# Available tables: ['ai_customer_context', 'dim_customers', 'dim_dates', 'dim_products', 'fct_order_lines', 'mart_country_sales', 'mart_monthly_revenue', 'mart_top_customers', 'raw_transactions', 'stg_transactions']
# Extracted 4415 SQL records to /content/drive/MyDrive/projects/enterprise-rag-langchain-platform/data/exports/sql_context.pkl
# /usr/local/lib/python3.12/dist-packages/pypdf/_crypt_providers/_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from this module in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4
# Ingested 4 document chunks to /content/drive/MyDrive/projects/enterprise-rag-langchain-platform/data/exports/doc_chunks.pkl
# 2026-04-14 19:09:50.203731: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-14 19:09:50.212269: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776193790.221949    3638 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776193790.225226    3638 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776193790.233495    3638 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776193790.233522    3638 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776193790.233524    3638 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776193790.233525    3638 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-14 19:09:50.236011: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# modules.json: 100% 349/349 [00:00<00:00, 5.67MB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 2.59MB/s]
# README.md: 10.5kB [00:00, 76.8MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 1.28MB/s]
# config.json: 100% 612/612 [00:00<00:00, 13.1MB/s]
# model.safetensors: 100% 90.9M/90.9M [00:00<00:00, 106MB/s]
# tokenizer_config.json: 100% 350/350 [00:00<00:00, 7.23MB/s]
# vocab.txt: 232kB [00:00, 23.4MB/s]
# tokenizer.json: 466kB [00:00, 76.0MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 2.88MB/s]
# config.json: 100% 190/190 [00:00<00:00, 3.98MB/s]
# Built SQL LangChain FAISS store with 4415 documents
# Built DOC LangChain FAISS store with 4 documents
# 2026-04-14 19:10:07.069386: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-14 19:10:07.078013: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776193807.087622    3988 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776193807.090845    3988 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776193807.099169    3988 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776193807.099184    3988 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776193807.099186    3988 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776193807.099187    3988 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-14 19:10:07.101699: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ====================================================================================================
# Question: Which customers are high value and what support policy applies to them?
# Routing mode: hybrid
#
# Answer summary:
# Structured business context indicates:
# - Customer 16808.0 is a low_value customer from United Kingdom. Lifetime value is 288.42 across 2 invoices. Last order timestamp was 2011-09-01 19:34:00. They purchased 21 distinct products.
# - Customer 16803.0 is a low_value customer from United Kingdom. Lifetime value is 332.30 across 1 invoices. Last order timestamp was 2011-10-05 14:28:00. They purchased 24 distinct products.
# - Customer 16809.0 is a low_value customer from United Kingdom. Lifetime value is 914.69 across 5 invoices. Last order timestamp was 2011-11-16 15:45:00. They purchased 79 distinct products.
#
# Document guidance indicates:
# - Loyalty Program Customers are grouped into Standard, Growth, and Premium tiers based on annual revenue and purchase consistency. Premium customers receive priority support and proactive account reviews. Growth customers should be evaluated for upsell campaigns when their recent monthly purchase volume is rising.
# - Support Escalation Guide Any customer with lifetime revenue above $50,000 and repeated issues should be escalated to customer success. Refund disputes above $2,500 should be reviewed jointly by finance and support. If multiple customers from the same country report delays, the regional operations manager should be notified.
# - Sales Strategy Memo Focus retention and upsell efforts on high-revenue customers and countries. Where monthly revenue dips, commercial teams should investigate support, discounting, and fulfillment issues. The customer summary context table should be used to prioritize outreach.
#
# Sources used:
# - loyalty_program.txt [doc]: Loyalty Program Customers are grouped into Standard, Growth, and Premium tiers based on annual revenue and purchase consistency. Premium customers receive priority support and proactive account reviews. Growth customers should be evaluated for upsell campaigns when their recent monthly purchase volume is rising.
# - support_escalation.txt [doc]: Support Escalation Guide Any customer with lifetime revenue above $50,000 and repeated issues should be escalated to customer success. Refund disputes above $2,500 should be reviewed jointly by finance and support. If multiple customers from the same country report delays, the regional operations manager should be notified.
# - ai_customer_context [sql]: Customer 16808.0 is a low_value customer from United Kingdom. Lifetime value is 288.42 across 2 invoices. Last order timestamp was 2011-09-01 19:34:00. They purchased 21 distinct products.
# - ai_customer_context [sql]: Customer 16803.0 is a low_value customer from United Kingdom. Lifetime value is 332.30 across 1 invoices. Last order timestamp was 2011-10-05 14:28:00. They purchased 24 distinct products.
# - ai_customer_context [sql]: Customer 16809.0 is a low_value customer from United Kingdom. Lifetime value is 914.69 across 5 invoices. Last order timestamp was 2011-11-16 15:45:00. They purchased 79 distinct products.
# - ai_customer_context [sql]: Customer 16806.0 is a low_value customer from United Kingdom. Lifetime value is 801.49 across 4 invoices. Last order timestamp was 2011-08-28 15:27:00. They purchased 68 distinct products.
#
# ====================================================================================================
# Question: What does the loyalty program say about premium customers?
# Routing mode: doc
#
# Answer summary:
# Structured business context indicates:
# - Customer 17746.0 is a low_value customer from United Kingdom. Lifetime value is 110.25 across 1 invoices. Last order timestamp was 2011-04-13 14:31:00. They purchased 6 distinct products.
# - Customer 14215.0 is a low_value customer from United Kingdom. Lifetime value is 1789.72 across 6 invoices. Last order timestamp was 2011-11-28 12:19:00. They purchased 98 distinct products.
#
# Document guidance indicates:
# - Loyalty Program Customers are grouped into Standard, Growth, and Premium tiers based on annual revenue and purchase consistency. Premium customers receive priority support and proactive account reviews. Growth customers should be evaluated for upsell campaigns when their recent monthly purchase volume is rising.
# - Sales Strategy Memo Focus retention and upsell efforts on high-revenue customers and countries. Where monthly revenue dips, commercial teams should investigate support, discounting, and fulfillment issues. The customer summary context table should be used to prioritize outreach.
# - Support Escalation Guide Any customer with lifetime revenue above $50,000 and repeated issues should be escalated to customer success. Refund disputes above $2,500 should be reviewed jointly by finance and support. If multiple customers from the same country report delays, the regional operations manager should be notified.
#
# Sources used:
# - loyalty_program.txt [doc]: Loyalty Program Customers are grouped into Standard, Growth, and Premium tiers based on annual revenue and purchase consistency. Premium customers receive priority support and proactive account reviews. Growth customers should be evaluated for upsell campaigns when their recent monthly purchase volume is rising.
# - ai_customer_context [sql]: Customer 17746.0 is a low_value customer from United Kingdom. Lifetime value is 110.25 across 1 invoices. Last order timestamp was 2011-04-13 14:31:00. They purchased 6 distinct products.
# - ai_customer_context [sql]: Customer 14215.0 is a low_value customer from United Kingdom. Lifetime value is 1789.72 across 6 invoices. Last order timestamp was 2011-11-28 12:19:00. They purchased 98 distinct products.
# - sales_strategy.txt [doc]: Sales Strategy Memo Focus retention and upsell efforts on high-revenue customers and countries. Where monthly revenue dips, commercial teams should investigate support, discounting, and fulfillment issues. The customer summary context table should be used to prioritize outreach.
# - support_escalation.txt [doc]: Support Escalation Guide Any customer with lifetime revenue above $50,000 and repeated issues should be escalated to customer success. Refund disputes above $2,500 should be reviewed jointly by finance and support. If multiple customers from the same country report delays, the regional operations manager should be notified.
# - refund_policy.txt [doc]: Refund Policy Customers may request refunds within 30 days of invoice date for damaged, defective, or duplicate items. Orders above $5,000 should be reviewed by premium support before approval. If multiple refunds occur for a high-value customer, notify the account manager.
#
# ====================================================================================================
# Question: Which countries generate the most revenue?
# Routing mode: sql
#
# Answer summary:
# Structured business context indicates:
# - Country Switzerland generated 57089.90 in revenue across 54 invoices and 22 customers.
# - Country Netherlands generated 285446.34 in revenue across 95 invoices and 9 customers.
# - Country Saudi Arabia generated 145.92 in revenue across 1 invoices and 1 customers.
#
# Document guidance indicates:
# - Sales Strategy Memo Focus retention and upsell efforts on high-revenue customers and countries. Where monthly revenue dips, commercial teams should investigate support, discounting, and fulfillment issues. The customer summary context table should be used to prioritize outreach.
# - Support Escalation Guide Any customer with lifetime revenue above $50,000 and repeated issues should be escalated to customer success. Refund disputes above $2,500 should be reviewed jointly by finance and support. If multiple customers from the same country report delays, the regional operations manager should be notified.
#
# Sources used:
# - mart_country_sales [sql]: Country Switzerland generated 57089.90 in revenue across 54 invoices and 22 customers.
# - mart_country_sales [sql]: Country Netherlands generated 285446.34 in revenue across 95 invoices and 9 customers.
# - mart_country_sales [sql]: Country Saudi Arabia generated 145.92 in revenue across 1 invoices and 1 customers.
# - mart_country_sales [sql]: Country Brazil generated 1143.60 in revenue across 1 invoices and 1 customers.
# - mart_country_sales [sql]: Country Portugal generated 33747.10 in revenue across 58 invoices and 20 customers.
# - mart_country_sales [sql]: Country Norway generated 36165.44 in revenue across 36 invoices and 10 customers.
#
# ====================================================================================================
# Question: Summarize the monthly revenue trend and the sales strategy.
# Routing mode: sql
#
# Answer summary:
# Structured business context indicates:
# - In 2011-06, revenue was 761739.90 from 1576 invoices and 36056 order lines.
# - In 2011-12, revenue was 638792.68 from 839 invoices and 25135 order lines.
# - Top customer 13089.0 from United Kingdom generated 58825.83 in revenue across 97 invoices. Last order timestamp was 2011-12-07 09:02:00.
#
# Document guidance indicates:
# - Sales Strategy Memo Focus retention and upsell efforts on high-revenue customers and countries. Where monthly revenue dips, commercial teams should investigate support, discounting, and fulfillment issues. The customer summary context table should be used to prioritize outreach.
# - Loyalty Program Customers are grouped into Standard, Growth, and Premium tiers based on annual revenue and purchase consistency. Premium customers receive priority support and proactive account reviews. Growth customers should be evaluated for upsell campaigns when their recent monthly purchase volume is rising.
#
# Sources used:
# - sales_strategy.txt [doc]: Sales Strategy Memo Focus retention and upsell efforts on high-revenue customers and countries. Where monthly revenue dips, commercial teams should investigate support, discounting, and fulfillment issues. The customer summary context table should be used to prioritize outreach.
# - mart_monthly_revenue [sql]: In 2011-06, revenue was 761739.90 from 1576 invoices and 36056 order lines.
# - mart_monthly_revenue [sql]: In 2011-12, revenue was 638792.68 from 839 invoices and 25135 order lines.
# - mart_top_customers [sql]: Top customer 13089.0 from United Kingdom generated 58825.83 in revenue across 97 invoices. Last order timestamp was 2011-12-07 09:02:00.
# - mart_top_customers [sql]: Top customer 17841.0 from United Kingdom generated 40991.57 in revenue across 124 invoices. Last order timestamp was 2011-12-08 12:07:00.
# - mart_monthly_revenue [sql]: In 2011-02, revenue was 523631.89 from 1126 invoices and 27184 order lines.

# %%
# !ls data/exports
# !find data/vectorstore -maxdepth 2 -type f | sort
# Out:
# doc_chunks.pkl	sql_context.pkl
# data/vectorstore/doc_store/index.faiss
# data/vectorstore/doc_store/index.pkl
# data/vectorstore/sql_store/index.faiss
# data/vectorstore/sql_store/index.pkl

# %%
# !python -m src.extract_sql_context
# !python -m src.build_langchain_indexes
# !python -m src.run_demo
# Out:
# Available tables: ['ai_customer_context', 'dim_customers', 'dim_dates', 'dim_products', 'fct_order_lines', 'mart_country_sales', 'mart_monthly_revenue', 'mart_top_customers', 'raw_transactions', 'stg_transactions']
# Extracted 262 SQL records to /content/drive/MyDrive/projects/enterprise-rag-langchain-platform/data/exports/sql_context.pkl
# 2026-04-14 19:24:45.722558: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-14 19:24:45.731311: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776194685.740974    8653 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776194685.744240    8653 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776194685.752619    8653 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776194685.752637    8653 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776194685.752638    8653 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776194685.752640    8653 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-14 19:24:45.755181: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Built SQL LangChain FAISS store with 262 documents
# Built DOC LangChain FAISS store with 4 documents
# 2026-04-14 19:24:54.952137: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-14 19:24:54.960950: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776194694.970856    8906 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776194694.974200    8906 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776194694.982764    8906 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776194694.982784    8906 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776194694.982786    8906 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776194694.982787    8906 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-14 19:24:54.985326: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ====================================================================================================
# Question: Which customers are high value and what support policy applies to them?
# Routing mode: sql
#
# Final synthesized answer:
# Based on structured customer data and business policy documents, high-value customers should receive priority support, proactive engagement, and escalation to customer success when repeated issues occur. Loyalty guidance indicates that premium customers should also receive proactive account reviews and higher-touch support.
#
# Structured business context:
# - Among the top 200 customers by lifetime value, there are 20 high_value customers, 84 mid_value customers, and 96 low_value customers. High value customers should receive priority support, proactive engagement, and escalation when repeated issues occur.
# - High value customers are those with lifetime value above $50,000. These customers should receive priority support, proactive account reviews, and escalation to customer success when issues arise.
# - Customer 14088.0 is a high_value customer from United Kingdom. Lifetime value is 50491.81 across 13 invoices. Last order timestamp was 2011-11-29 16:16:00. They purchased 379 distinct products.
#
# Document guidance:
# - Loyalty Program Customers are grouped into Standard, Growth, and Premium tiers based on annual revenue and purchase consistency. Premium customers receive priority support and proactive account reviews. Growth customers should be evaluated for upsell campaigns when their recent monthly purchase volume is rising.
# - Support Escalation Guide Any customer with lifetime revenue above $50,000 and repeated issues should be escalated to customer success. Refund disputes above $2,500 should be reviewed jointly by finance and support. If multiple customers from the same country report delays, the regional operations manager should be notified.
# - Sales Strategy Memo Focus retention and upsell efforts on high-revenue customers and countries. Where monthly revenue dips, commercial teams should investigate support, discounting, and fulfillment issues. The customer summary context table should be used to prioritize outreach.
#
# Sources used:
# - summary [sql]: Among the top 200 customers by lifetime value, there are 20 high_value customers, 84 mid_value customers, and 96 low_value customers. High value customers should receive priority support, proactive engagement, and escalation when repeated issues occur.
# - summary [sql]: High value customers are those with lifetime value above $50,000. These customers should receive priority support, proactive account reviews, and escalation to customer success when issues arise.
# - ai_customer_context [sql]: Customer 14088.0 is a high_value customer from United Kingdom. Lifetime value is 50491.81 across 13 invoices. Last order timestamp was 2011-11-29 16:16:00. They purchased 379 distinct products.
# - ai_customer_context [sql]: Customer 15311.0 is a high_value customer from United Kingdom. Lifetime value is 60767.90 across 91 invoices. Last order timestamp was 2011-12-09 12:00:00. They purchased 567 distinct products.
# - ai_customer_context [sql]: Customer 14096.0 is a high_value customer from United Kingdom. Lifetime value is 65164.79 across 17 invoices. Last order timestamp was 2011-12-05 17:17:00. They purchased 1119 distinct products.
# - loyalty_program.txt [doc]: Loyalty Program Customers are grouped into Standard, Growth, and Premium tiers based on annual revenue and purchase consistency. Premium customers receive priority support and proactive account reviews. Growth customers should be evaluated for upsell campaigns when their recent monthly purchase volume is rising.
#
# ====================================================================================================
# Question: What does the loyalty program say about premium customers?
# Routing mode: doc
#
# Final synthesized answer:
# Based on structured customer data and business policy documents, high-value customers should receive priority support, proactive engagement, and escalation to customer success when repeated issues occur. Loyalty guidance indicates that premium customers should also receive proactive account reviews and higher-touch support.
#
# Structured business context:
# - Among the top 200 customers by lifetime value, there are 20 high_value customers, 84 mid_value customers, and 96 low_value customers. High value customers should receive priority support, proactive engagement, and escalation when repeated issues occur.
# - High value customers are those with lifetime value above $50,000. These customers should receive priority support, proactive account reviews, and escalation to customer success when issues arise.
#
# Document guidance:
# - Loyalty Program Customers are grouped into Standard, Growth, and Premium tiers based on annual revenue and purchase consistency. Premium customers receive priority support and proactive account reviews. Growth customers should be evaluated for upsell campaigns when their recent monthly purchase volume is rising.
# - Support Escalation Guide Any customer with lifetime revenue above $50,000 and repeated issues should be escalated to customer success. Refund disputes above $2,500 should be reviewed jointly by finance and support. If multiple customers from the same country report delays, the regional operations manager should be notified.
# - Sales Strategy Memo Focus retention and upsell efforts on high-revenue customers and countries. Where monthly revenue dips, commercial teams should investigate support, discounting, and fulfillment issues. The customer summary context table should be used to prioritize outreach.
#
# Sources used:
# - loyalty_program.txt [doc]: Loyalty Program Customers are grouped into Standard, Growth, and Premium tiers based on annual revenue and purchase consistency. Premium customers receive priority support and proactive account reviews. Growth customers should be evaluated for upsell campaigns when their recent monthly purchase volume is rising.
# - summary [sql]: Among the top 200 customers by lifetime value, there are 20 high_value customers, 84 mid_value customers, and 96 low_value customers. High value customers should receive priority support, proactive engagement, and escalation when repeated issues occur.
# - summary [sql]: High value customers are those with lifetime value above $50,000. These customers should receive priority support, proactive account reviews, and escalation to customer success when issues arise.
# - support_escalation.txt [doc]: Support Escalation Guide Any customer with lifetime revenue above $50,000 and repeated issues should be escalated to customer success. Refund disputes above $2,500 should be reviewed jointly by finance and support. If multiple customers from the same country report delays, the regional operations manager should be notified.
# - sales_strategy.txt [doc]: Sales Strategy Memo Focus retention and upsell efforts on high-revenue customers and countries. Where monthly revenue dips, commercial teams should investigate support, discounting, and fulfillment issues. The customer summary context table should be used to prioritize outreach.
# - refund_policy.txt [doc]: Refund Policy Customers may request refunds within 30 days of invoice date for damaged, defective, or duplicate items. Orders above $5,000 should be reviewed by premium support before approval. If multiple refunds occur for a high-value customer, notify the account manager.
#
# ====================================================================================================
# Question: Which countries generate the most revenue?
# Routing mode: sql
#
# Final synthesized answer:
# Based on structured sales data, the highest-revenue countries should be prioritized for regional sales planning, customer retention, and commercial outreach.
#
# Structured business context:
# - Country Switzerland generated 57089.90 in revenue across 54 invoices and 22 customers.
# - Country Netherlands generated 285446.34 in revenue across 95 invoices and 9 customers.
# - Country Portugal generated 33747.10 in revenue across 58 invoices and 20 customers.
#
# Document guidance:
# - Sales Strategy Memo Focus retention and upsell efforts on high-revenue customers and countries. Where monthly revenue dips, commercial teams should investigate support, discounting, and fulfillment issues. The customer summary context table should be used to prioritize outreach.
# - Support Escalation Guide Any customer with lifetime revenue above $50,000 and repeated issues should be escalated to customer success. Refund disputes above $2,500 should be reviewed jointly by finance and support. If multiple customers from the same country report delays, the regional operations manager should be notified.
# - Loyalty Program Customers are grouped into Standard, Growth, and Premium tiers based on annual revenue and purchase consistency. Premium customers receive priority support and proactive account reviews. Growth customers should be evaluated for upsell campaigns when their recent monthly purchase volume is rising.
#
# Sources used:
# - mart_country_sales [sql]: Country Switzerland generated 57089.90 in revenue across 54 invoices and 22 customers.
# - mart_country_sales [sql]: Country Netherlands generated 285446.34 in revenue across 95 invoices and 9 customers.
# - mart_country_sales [sql]: Country Portugal generated 33747.10 in revenue across 58 invoices and 20 customers.
# - mart_country_sales [sql]: Country Norway generated 36165.44 in revenue across 36 invoices and 10 customers.
# - mart_country_sales [sql]: Country France generated 209715.11 in revenue across 392 invoices and 88 customers.
# - summary [sql]: The top revenue-generating country was United Kingdom with 9025222.08 in revenue. Country-level performance should be used to guide regional sales prioritization.
#
# ====================================================================================================
# Question: Summarize the monthly revenue trend and the sales strategy.
# Routing mode: sql
#
# Final synthesized answer:
# The structured revenue records show variation across months, and the supporting business documents suggest that shifts in support quality, fulfillment, pricing, and customer engagement should be reviewed when revenue trends decline.
#
# Structured business context:
# - Monthly revenue peaked in 2011-11 at 1509496.33. The lowest month was 2011-02 at 523631.89. Revenue fluctuated across the year and should be reviewed alongside sales strategy and customer retention efforts.
# - In 2011-06, revenue was 761739.90 from 1576 invoices and 36056 order lines.
# - In 2011-12, revenue was 638792.68 from 839 invoices and 25135 order lines.
#
# Document guidance:
# - Sales Strategy Memo Focus retention and upsell efforts on high-revenue customers and countries. Where monthly revenue dips, commercial teams should investigate support, discounting, and fulfillment issues. The customer summary context table should be used to prioritize outreach.
# - Loyalty Program Customers are grouped into Standard, Growth, and Premium tiers based on annual revenue and purchase consistency. Premium customers receive priority support and proactive account reviews. Growth customers should be evaluated for upsell campaigns when their recent monthly purchase volume is rising.
# - Support Escalation Guide Any customer with lifetime revenue above $50,000 and repeated issues should be escalated to customer success. Refund disputes above $2,500 should be reviewed jointly by finance and support. If multiple customers from the same country report delays, the regional operations manager should be notified.
#
# Sources used:
# - summary [sql]: Monthly revenue peaked in 2011-11 at 1509496.33. The lowest month was 2011-02 at 523631.89. Revenue fluctuated across the year and should be reviewed alongside sales strategy and customer retention efforts.
# - sales_strategy.txt [doc]: Sales Strategy Memo Focus retention and upsell efforts on high-revenue customers and countries. Where monthly revenue dips, commercial teams should investigate support, discounting, and fulfillment issues. The customer summary context table should be used to prioritize outreach.
# - mart_monthly_revenue [sql]: In 2011-06, revenue was 761739.90 from 1576 invoices and 36056 order lines.
# - mart_monthly_revenue [sql]: In 2011-12, revenue was 638792.68 from 839 invoices and 25135 order lines.
# - mart_monthly_revenue [sql]: In 2011-02, revenue was 523631.89 from 1126 invoices and 27184 order lines.
# - summary [sql]: The top revenue-generating country was United Kingdom with 9025222.08 in revenue. Country-level performance should be used to guide regional sales prioritization.
